# %%
import sys

# add local directory to system path
sys.path.append("./")
from attack_flow_extension import flow
import argparse
from typing import Any
import pgmpy
from collections import defaultdict
import stix2
import json
from mitreattack.stix20 import MitreAttackData

# %%
class TechniquesArray:
    def __init__(self):
        self.techniques = []

    def add_or_increment_technique(self, technique):
        # Check if the technique exists in the array
        for item in self.techniques:
            if item['name'] == technique:
                # If it exists, increment its counter
                item['counter'] += 1
                #print(str(item))
                return
        
        # If the technique doesn't exist, add it with a counter of 1
        self.techniques.append({'name': technique, 'counter': 1})

    def print_techniques(self):
        for item in self.techniques:
            print(f"Technique: {item['name']}, Counter: {item['counter']}")
    
    def __str__(self):
        return "\n".join([f"Technique: {item['name']}, Counter: {item['counter']}" for item in self.techniques])
    
    def get_technique_count(self, technique: str) -> int:
        for item in self.techniques:
            if item['name'] == technique:
                return item['counter']
        return 0  # Technique not found

    def get_technique(self, technique: str) -> dict:
        for item in self.techniques:
            if item['name'] == technique:
                return item
        return {}  # Technique not found

# Example usage

# %%
mitre_data=MitreAttackData("enterprise-attack.json")

# %%
all_techniques=mitre_data.get_techniques()
#x = mitre_data.get_attack_id()
#print(x)
techCount =0
for tech in all_techniques:
    techCount += 1
print(techCount)
# Out:
# 780

# %%
tech_array = TechniquesArray()
campaigns = mitre_data.get_all_techniques_used_by_all_campaigns()
print(mitre_data)

camCounter=0

for campaign in campaigns.keys():
    camCounter +=1
    attack_pattern=mitre_data.get_techniques_used_by_campaign(campaign)
    for pattern in attack_pattern:
        name = pattern.get("object").get("name")
        id = pattern.get("object").get("external_references")[0].get("external_id")
        tech_array.add_or_increment_technique(id)
       
print(tech_array)
tech_array_w_prob = {}
techCounter=0
for i in all_techniques:
    name=i.get("name")
    for ref in i['external_references']:
            if 'external_id' in ref:
                id = ref['external_id']
                count=tech_array.get_technique_count(id)
                prob = count/camCounter
                attackPattern = mitre_data.get_object_by_attack_id(id, 'attack-pattern')
                stixID = attackPattern.get('id')
                tech_array_w_prob[techCounter]={'Name': name, 'ID': id, 'Count':count,"Probability": prob, 'STIX ID':stixID}
    techCounter +=1
print(tech_array_w_prob)
# Out:
# <mitreattack.stix20.MitreAttackData.MitreAttackData object at 0x7fc9ea9f0bc0>
# Technique: T1572, Counter: 5
# Technique: T1190, Counter: 8
# Technique: T1087.004, Counter: 1
# Technique: T1102, Counter: 3
# Technique: T1069.003, Counter: 1
# Technique: T1598.004, Counter: 1
# Technique: T1003.006, Counter: 3
# Technique: T1105, Counter: 18
# Technique: T1098.003, Counter: 2
# Technique: T1578.002, Counter: 1
# Technique: T1046, Counter: 4
# Technique: T1021.007, Counter: 1
# Technique: T1213.002, Counter: 1
# Technique: T1078.004, Counter: 2
# Technique: T1087.003, Counter: 1
# Technique: T1598.001, Counter: 1
# Technique: T1621, Counter: 1
# Technique: T1098.005, Counter: 2
# Technique: T1219, Counter: 4
# Technique: T1047, Counter: 9
# Technique: T1656, Counter: 2
# Technique: T1098.001, Counter: 2
# Technique: T1133, Counter: 8
# Technique: T1530, Counter: 1
# Technique: T1588.002, Counter: 17
# Technique: T1589.001, Counter: 2
# Technique: T1090, Counter: 4
# Technique: T1566.004, Counter: 1
# Technique: T1012, Counter: 1
# Technique: T1003.001, Counter: 5
# Technique: T1056.001, Counter: 3
# Technique: T1518.001, Counter: 2
# Technique: T1018, Counter: 7
# Technique: T1573.002, Counter: 2
# Technique: T1587.001, Counter: 8
# Technique: T1059.003, Counter: 11
# Technique: T1555.005, Counter: 1
# Technique: T1552.004, Counter: 2
# Technique: T1119, Counter: 2
# Technique: T1049, Counter: 3
# Technique: T1585.002, Counter: 5
# Technique: T1124, Counter: 3
# Technique: T1571, Counter: 3
# Technique: T1111, Counter: 1
# Technique: T1090.003, Counter: 2
# Technique: T1074.001, Counter: 5
# Technique: T1033, Counter: 6
# Technique: T1071.001, Counter: 10
# Technique: T1569.002, Counter: 2
# Technique: T1005, Counter: 12
# Technique: T1115, Counter: 1
# Technique: T1583.004, Counter: 4
# Technique: T1560.001, Counter: 8
# Technique: T1106, Counter: 4
# Technique: T1069.001, Counter: 3
# Technique: T1078, Counter: 5
# Technique: T1135, Counter: 3
# Technique: T1070.004, Counter: 7
# Technique: T1001, Counter: 1
# Technique: T1558.003, Counter: 2
# Technique: T1021.002, Counter: 4
# Technique: T1570, Counter: 6
# Technique: T1059.005, Counter: 13
# Technique: T1016.001, Counter: 2
# Technique: T1087.002, Counter: 4
# Technique: T1078.002, Counter: 6
# Technique: T1055, Counter: 4
# Technique: T1083, Counter: 7
# Technique: T1589, Counter: 2
# Technique: T1059.006, Counter: 2
# Technique: T1112, Counter: 4
# Technique: T1090.001, Counter: 2
# Technique: T1041, Counter: 5
# Technique: T1036.005, Counter: 10
# Technique: T1562.004, Counter: 2
# Technique: T1007, Counter: 2
# Technique: T1120, Counter: 2
# Technique: T1027.005, Counter: 2
# Technique: T1053.005, Counter: 10
# Technique: T1082, Counter: 8
# Technique: T1027.010, Counter: 5
# Technique: T1059.001, Counter: 10
# Technique: T1095, Counter: 4
# Technique: T1016, Counter: 7
# Technique: T1070.001, Counter: 1
# Technique: T1505.003, Counter: 6
# Technique: T1518, Counter: 2
# Technique: T1078.003, Counter: 2
# Technique: T1057, Counter: 7
# Technique: T1606.002, Counter: 1
# Technique: T1114.002, Counter: 1
# Technique: T1069.002, Counter: 2
# Technique: T1584.001, Counter: 4
# Technique: T1550, Counter: 1
# Technique: T1555.003, Counter: 1
# Technique: T1665, Counter: 1
# Technique: T1098.002, Counter: 1
# Technique: T1021.001, Counter: 5
# Technique: T1562.001, Counter: 4
# Technique: T1213, Counter: 1
# Technique: T1568, Counter: 5
# Technique: T1140, Counter: 7
# Technique: T1069, Counter: 1
# Technique: T1021.006, Counter: 1
# Technique: T1550.001, Counter: 1
# Technique: T1553.002, Counter: 4
# Technique: T1218.011, Counter: 7
# Technique: T1546.003, Counter: 2
# Technique: T1213.003, Counter: 1
# Technique: T1539, Counter: 1
# Technique: T1606.001, Counter: 1
# Technique: T1550.004, Counter: 1
# Technique: T1074.002, Counter: 2
# Technique: T1199, Counter: 1
# Technique: T1070.006, Counter: 3
# Technique: T1070, Counter: 2
# Technique: T1562.002, Counter: 2
# Technique: T1036.004, Counter: 4
# Technique: T1482, Counter: 2
# Technique: T1555, Counter: 1
# Technique: T1195.002, Counter: 1
# Technique: T1070.008, Counter: 1
# Technique: T1484.002, Counter: 1
# Technique: T1583.001, Counter: 12
# Technique: T1087, Counter: 1
# Technique: T1048.002, Counter: 1
# Technique: T1027.013, Counter: 6
# Technique: T1574.011, Counter: 1
# Technique: T1588.004, Counter: 1
# Technique: T1071.002, Counter: 1
# Technique: T1548.002, Counter: 1
# Technique: T1543.003, Counter: 3
# Technique: T1204.002, Counter: 9
# Technique: T1036, Counter: 4
# Technique: T1036.008, Counter: 2
# Technique: T1505.001, Counter: 1
# Technique: T1136, Counter: 1
# Technique: T1027, Counter: 3
# Technique: T1027.002, Counter: 6
# Technique: T1098, Counter: 1
# Technique: T1110, Counter: 2
# Technique: T1136.002, Counter: 2
# Technique: T1554, Counter: 2
# Technique: T1566.001, Counter: 7
# Technique: T1040, Counter: 1
# Technique: T1614.001, Counter: 1
# Technique: T1608.001, Counter: 7
# Technique: T1585.001, Counter: 2
# Technique: T1547.001, Counter: 2
# Technique: T1497.001, Counter: 2
# Technique: T1608.002, Counter: 2
# Technique: T1573.001, Counter: 2
# Technique: T1204.001, Counter: 6
# Technique: T1591, Counter: 1
# Technique: T1221, Counter: 2
# Technique: T1497.003, Counter: 1
# Technique: T1534, Counter: 1
# Technique: T1583.006, Counter: 2
# Technique: T1566.003, Counter: 1
# Technique: T1591.004, Counter: 1
# Technique: T1588.003, Counter: 1
# Technique: T1587.002, Counter: 1
# Technique: T1505.004, Counter: 1
# Technique: T1218.010, Counter: 2
# Technique: T1567.002, Counter: 2
# Technique: T1622, Counter: 1
# Technique: T1220, Counter: 1
# Technique: T1584.004, Counter: 3
# Technique: T1593.001, Counter: 1
# Technique: T1566.002, Counter: 6
# Technique: T1055.001, Counter: 1
# Technique: T1486, Counter: 2
# Technique: T1588.001, Counter: 4
# Technique: T1030, Counter: 2
# Technique: T1039, Counter: 1
# Technique: T1059.007, Counter: 3
# Technique: T1218.005, Counter: 2
# Technique: T1027.009, Counter: 1
# Technique: T1020, Counter: 1
# Technique: T1203, Counter: 2
# Technique: T1127.001, Counter: 1
# Technique: T1201, Counter: 1
# Technique: T1087.001, Counter: 1
# Technique: T1027.011, Counter: 1
# Technique: T1003.002, Counter: 3
# Technique: T1574.002, Counter: 1
# Technique: T1547.006, Counter: 1
# Technique: T1114.001, Counter: 1
# Technique: T1008, Counter: 1
# Technique: T1550.002, Counter: 1
# Technique: T1110.002, Counter: 1
# Technique: T1102.002, Counter: 1
# Technique: T1001.002, Counter: 1
# Technique: T1027.003, Counter: 2
# Technique: T1583.003, Counter: 1
# Technique: T1021.004, Counter: 2
# Technique: T1546.012, Counter: 1
# Technique: T1048.003, Counter: 1
# Technique: T1068, Counter: 1
# Technique: T1102.001, Counter: 1
# Technique: T1574, Counter: 1
# Technique: T1001.003, Counter: 1
# Technique: T1134, Counter: 1
# Technique: T1567, Counter: 1
# Technique: T1560.003, Counter: 1
# Technique: T1059, Counter: 2
# Technique: T1497, Counter: 1
# Technique: T1559.002, Counter: 1
# Technique: T1595.002, Counter: 1
# Technique: T1205, Counter: 1
# Technique: T1071.004, Counter: 1
# Technique: T1594, Counter: 1
# Technique: T1003.003, Counter: 1
# Technique: T1584.008, Counter: 1
# Technique: T1056.003, Counter: 2
# Technique: T1543.002, Counter: 1
# Technique: T1485, Counter: 1
# Technique: T1484.001, Counter: 1
# Technique: T1587.003, Counter: 1
# Technique: T1573, Counter: 1
# Technique: T1595, Counter: 1
# Technique: T1072, Counter: 1
# Technique: T1189, Counter: 2
# Technique: T1608.004, Counter: 1
# {0: {'Name': 'Extra Window Memory Injection', 'ID': 'T1055.011', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--0042a9f5-f053-4769-b3ef-9ad018dfa298'}, 1: {'Name': 'Scheduled Task', 'ID': 'T1053.005', 'Count': 10, 'Probability': 0.37037037037037035, 'STIX ID': 'attack-pattern--005a06c6-14bf-4118-afa0-ebcd8aebb0c9'}, 2: {'Name': 'Socket Filters', 'ID': 'T1205.002', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--005cc321-08ce-4d17-b1ea-cb5275926520'}, 3: {'Name': 'Indicator Removal from Tools', 'ID': 'T1066', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--00d0b012-8a03-410e-95de-5826bf542de6'}, 4: {'Name': 'Archive via Utility', 'ID': 'T1560.001', 'Count': 8, 'Probability': 0.2962962962962963, 'STIX ID': 'attack-pattern--00f90846-cbd1-4fc5-9233-df5c2bf2a662'}, 5: {'Name': 'VNC', 'ID': 'T1021.005', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--01327cde-66c4-4123-bf34-5f258d59457b'}, 6: {'Name': 'Windows Management Instrumentation', 'ID': 'T1047', 'Count': 9, 'Probability': 0.3333333333333333, 'STIX ID': 'attack-pattern--01a5a209-b94c-450b-b7f9-946497d91055'}, 7: {'Name': 'Malicious Shell Modification', 'ID': 'T1156', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--01df3350-ce05-4bdf-bdf8-0a919a66d4a8'}, 8: {'Name': 'Screen Capture', 'ID': 'T1113', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--0259baeb-9f63-4c69-bf10-eb038c390688'}, 9: {'Name': 'Fileless Storage', 'ID': 'T1027.011', 'Count': 1, 'Probability': 0.037037037037037035, 'STIX ID': 'attack-pattern--02c5abff-30bf-4703-ab92-1f6072fae939'}, 10: {'Name': 'Bootkit', 'ID': 'T1067', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--02fefddc-fb1b-423f-a76b-7552dd211d4d'}, 11: {'Name': 'Boot or Logon Initialization Scripts', 'ID': 'T1037', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--03259939-0b57-482f-8eb5-87c0e0d54334'}, 12: {'Name': 'Adversary-in-the-Middle', 'ID': 'T1557', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--035bb001-ab69-4a0b-9f6c-2de8b09e1b9d'}, 13: {'Name': 'System Owner/User Discovery', 'ID': 'T1033', 'Count': 6, 'Probability': 0.2222222222222222, 'STIX ID': 'attack-pattern--03d7999c-1f4c-42cc-8373-e7690d318104'}, 14: {'Name': 'Acquire Infrastructure', 'ID': 'T1583', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--0458aab9-ad42-4eac-9e22-706a95bafee2'}, 15: {'Name': 'Rundll32', 'ID': 'T1218.011', 'Count': 7, 'Probability': 0.25925925925925924, 'STIX ID': 'attack-pattern--045d0922-2310-4e60-b5e4-3302302cb3c5'}, 16: {'Name': 'Container and Resource Discovery', 'ID': 'T1613', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--0470e792-32f8-46b0-a351-652bc35e9336'}, 17: {'Name': 'Serverless', 'ID': 'T1583.007', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--04a5a8ab-3bc8-4c83-95c9-55274a89786d'}, 18: {'Name': 'Hidden Window', 'ID': 'T1143', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--04ee0cb7-dac3-4c6c-9387-4c6aa096f4cf'}, 19: {'Name': 'LC_LOAD_DYLIB Addition', 'ID': 'T1161', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--04ef4356-8926-45e2-9441-634b6f3dcecb'}, 20: {'Name': 'Standard Encoding', 'ID': 'T1132.001', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--04fd5427-79c7-44ea-ae13-11b24778ff1c'}, 21: {'Name': 'Embedded Payloads', 'ID': 'T1027.009', 'Count': 1, 'Probability': 0.037037037037037035, 'STIX ID': 'attack-pattern--0533ab23-3f7d-463f-9bd8-634d27e4dee1'}, 22: {'Name': 'Plist Modification', 'ID': 'T1150', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--06780952-177c-4247-b978-79c357fb311f'}, 23: {'Name': 'Pluggable Authentication Modules', 'ID': 'T1556.003', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--06c00069-771a-4d57-8ef5-d3718c1a8771'}, 24: {'Name': 'Revert Cloud Instance', 'ID': 'T1578.004', 'Count': 0, 'Probability': 0.0, 'STIX ID': 'attack-pattern--0708ae90-d0eb-4938-9a76-d0fc94f6eec1'}, 25: {'Name': 'HISTCONTROL', 'ID': 'CAPEC-13', ...
