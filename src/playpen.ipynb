# %%
import pgmpy
import stix2
import json

# %%
from typing import Any
def read_flow_file(name)-> Any:
    """
    Read a flow file and return the data.

    Parameters:
    name (str): The name of the flow file to read.

    Returns:
    bundle (stix2.Bundle): The parsed STIX bundle data.

    """
    with open(name, "r", encoding="utf-8") as file:
        data = json.load(file)
        return data

# %%
custom_properties={
                        "x_foo": "bar"
                    }

# %%
data = read_flow_file("attack-flow-example.json")

# %%
bundle = stix2.parse(data)#allow_custom=True)
bundle
# Out:
# ---------------------------------------------------------------------------
# CustomContentError                        Traceback (most recent call last)
# File /workspaces/ATTACK-RISK/.venv/lib/python3.12/site-packages/stix2/base.py:50, in _STIXBase._check_property(self, prop_name, prop, kwargs, allow_custom)
#      49 try:
# ---> 50     kwargs[prop_name], has_custom = prop.clean(
#      51         kwargs[prop_name], allow_custom,
#      52     )
#      53 except InvalidValueError:
#      54     # No point in wrapping InvalidValueError in another
#      55     # InvalidValueError... so let those propagate.
#
# File /workspaces/ATTACK-RISK/.venv/lib/python3.12/site-packages/stix2/properties.py:240, in ListProperty.clean(self, value, allow_custom)
#     239 for item in value:
# --> 240     valid, temp_custom = self.contained.clean(item, allow_custom)
#     241     result.append(valid)
#
# File /workspaces/ATTACK-RISK/.venv/lib/python3.12/site-packages/stix2/properties.py:891, in STIXObjectProperty.clean(self, value, allow_custom)
#     887 if not allow_custom and has_custom:
#     888     # parse() will ignore the caller's allow_custom=False request if
#     889     # the object type is registered and dictified has a
#     890     # "custom_properties" key.  So we have to do another check here.
# --> 891     raise CustomContentError(
#     892         "customized {} object found".format(
#     893             parsed_obj["type"],
#     894         ),
#     895     )
#     897 return parsed_obj, has_custom
#
# CustomContentError: customized attack-flow object found
#
# The above exception was the direct cause of the following exception:
#
# InvalidValueError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 bundle = stix2.parse(data)#allow_custom=True)
#       2 bundle
#
# File /workspaces/ATTACK-RISK/.venv/lib/python3.12/site-packages/stix2/parsing.py:40, in parse(data, allow_custom, version)
#      37 obj = _get_dict(data)
#      39 # convert dict to full python-stix2 obj
# ---> 40 obj = dict_to_stix2(obj, allow_custom, version)
#      42 return obj
#
# File /workspaces/ATTACK-RISK/.venv/lib/python3.12/site-packages/stix2/parsing.py:99, in dict_to_stix2(stix_dict, allow_custom, version)
#      96             return stix_dict
#      97     raise ParseError("Can't parse unknown object type '%s'! For custom types, use the CustomObject decorator." % obj_type)
# ---> 99 return obj_class(allow_custom=allow_custom, **stix_dict)
#
# File /workspaces/ATTACK-RISK/.venv/lib/python3.12/site-packages/stix2/v21/bundle.py:35, in Bundle.__init__(self, *args, **kwargs)
#      31             obj_list.append(arg)
#      33     kwargs['objects'] = obj_list + kwargs.get('objects', [])
# ---> 35 super(Bundle, self).__init__(**kwargs)
#
# File /workspaces/ATTACK-RISK/.venv/lib/python3.12/site-packages/stix2/base.py:203, in _STIXBase.__init__(self, allow_custom, **kwargs)
#     201     prop = defined_properties.get(prop_name)
#     202     if prop:
# --> 203         temp_custom = self._check_property(
#     204             prop_name, prop, setting_kwargs, allow_custom,
#     205         )
#     207         has_custom = has_custom or temp_custom
#     209 # Detect any missing required properties
#
# File /workspaces/ATTACK-RISK/.venv/lib/python3.12/site-packages/stix2/base.py:58, in _STIXBase._check_property(self, prop_name, prop, kwargs, allow_custom)
#      56         raise
#      57     except Exception as exc:
# ---> 58         raise InvalidValueError(
#      59             self.__class__, prop_name, reason=str(exc),
#      60         ) from exc
#      62 return has_custom
#
# InvalidValueError: Invalid value for Bundle 'objects': customized attack-flow object found

# %%
import json
from stix2 import CustomObject, properties, parse

# Load the Attack Flow schema
schema_path = "attack-flow-schema-2.0.0.json"
with open(schema_path, 'r') as f:
    attack_flow_schema = json.load(f)

import stix2
import stix2.properties

# Define the extension ID
ATTACK_FLOW_EXTENSION_DEFINITION_ID = 'extension-definition--fb9c968a-745b-4ade-9b25-c324172197f4'

# Custom Observable for Attack Flow
@stix2.v21.CustomObservable(
    'attack-flow', [
        ('name', stix2.properties.StringProperty(required=True)),
        ('description', stix2.properties.StringProperty(required=False)),
        ('scope', stix2.properties.StringProperty(required=True)),
        ('start_refs', stix2.properties.ListProperty(stix2.properties.StringProperty(), required=True))
    ], ['name', 'scope', 'start_refs'], ATTACK_FLOW_EXTENSION_DEFINITION_ID,
)
class AttackFlow:
    pass

# Custom Observable for Attack Action
@stix2.v21.CustomObservable(
    'attack-action', [
        ('name', stix2.properties.StringProperty(required=True)),
        ('tactic_id', stix2.properties.StringProperty(required=False)),
        ('tactic_ref', stix2.properties.StringProperty(required=False)),
        ('technique_id', stix2.properties.StringProperty(required=False)),
        ('technique_ref', stix2.properties.StringProperty(required=False)),
        ('description', stix2.properties.StringProperty(required=False)),
        ('execution_start', stix2.properties.TimestampProperty(required=False)),
        ('execution_end', stix2.properties.TimestampProperty(required=False)),
        ('command_ref', stix2.properties.StringProperty(required=False)),
        ('asset_refs', stix2.properties.ListProperty(stix2.properties.StringProperty(), required=False)),
        ('effect_refs', stix2.properties.ListProperty(stix2.properties.StringProperty(), required=False))
    ], ['name'], ATTACK_FLOW_EXTENSION_DEFINITION_ID,
)
class AttackAction:
    pass

# Custom Observable for Attack Condition
@stix2.v21.CustomObservable(
    'attack-condition', [
        ('description', stix2.properties.StringProperty(required=True)),
        ('pattern', stix2.properties.StringProperty(required=False)),
        ('pattern_type', stix2.properties.StringProperty(required=False)),
        ('pattern_version', stix2.properties.StringProperty(required=False)),
        ('on_true_refs', stix2.properties.ListProperty(stix2.properties.StringProperty(), required=False)),
        ('on_false_refs', stix2.properties.ListProperty(stix2.properties.StringProperty(), required=False))
    ], ['description'], ATTACK_FLOW_EXTENSION_DEFINITION_ID,
)
class AttackCondition:
    pass

# Custom Observable for Attack Operator
@stix2.v21.CustomObservable(
    'attack-operator', [
        ('operator', stix2.properties.StringProperty(required=True)),
        ('effect_refs', stix2.properties.ListProperty(stix2.properties.StringProperty(), required=True))
    ], ['operator', 'effect_refs'], ATTACK_FLOW_EXTENSION_DEFINITION_ID,
)
class AttackOperator:
    pass

# Custom Observable for Attack Asset
@stix2.v21.CustomObservable(
    'attack-asset', [
        ('name', stix2.properties.StringProperty(required=True)),
        ('description', stix2.properties.StringProperty(required=False)),
        ('object_ref', stix2.properties.StringProperty(required=False))
    ], ['name'], ATTACK_FLOW_EXTENSION_DEFINITION_ID,
)
class AttackAsset:
    pass

# Create an instance of Attack Flow
attack_flow = AttackFlow(
    id='attack-flow--e9ec3a4b-f787-4e81-a3d9-4cfe017ebc2f',
    name='Example Attack Flow',
    description='This is an example of an Attack Flow.',
    scope='incident',
    start_refs=[
        'attack-action--37345417-3ee0-4e11-b421-1d4be68e6f15'
    ]
)

# Create an instance of Attack Action
attack_action = AttackAction(
    id='attack-action--37345417-3ee0-4e11-b421-1d4be68e6f15',
    name='Example Attack Action',
    tactic_id='TA0001',
    technique_id='T0001',
    description='This is an example of an Attack Action.',
    execution_start='2022-01-01T00:00:00Z',
    execution_end='2022-01-01T01:00:00Z'
)

# Create an instance of Attack Condition
attack_condition = AttackCondition(
    id='attack-condition--7e809f5b-319a-4b3f-82fe-e4dc09af5088',
    description='Example Condition',
    pattern='[file:hashes.md5 = "d41d8cd98f00b204e9800998ecf8427e"]',
    pattern_type='stix',
    pattern_version='2.1'
)

# Create an instance of Attack Operator
attack_operator = AttackOperator(
    id='attack-operator--609d7adf-a3d2-44e8-82de-4b30e3fb97be',
    operator='AND',
    effect_refs=[
        'attack-condition--7e809f5b-319a-4b3f-82fe-e4dc09af5088'
    ]
)

# Create an instance of Attack Asset
attack_asset = AttackAsset(
    id='attack-asset--f7edf4aa-29ec-47aa-b4f6-c42dfbe2ac20',
    name='Example Asset',
    description='This is an example of an Attack Asset.',
    object_ref='identity--b1da8c3e-34d8-470f-9d2b-392e275f1f7d'
)

# Serialize and print the instances
print(attack_flow.serialize(pretty=True))
print(attack_action.serialize(pretty=True))
print(attack_condition.serialize(pretty=True))
print(attack_operator.serialize(pretty=True))
print(attack_asset.serialize(pretty=True))
# Out:
# ---------------------------------------------------------------------------
# DuplicateRegistrationError                Traceback (most recent call last)
# Cell In[22], line 11
#       7     attack_flow_schema = json.load(f)
#      10 # Define Custom STIX Objects
# ---> 11 @CustomObject(
#      12     'attack-flow', [
#      13         ('type', properties.StringProperty(required=True, fixed='attack-flow')),
#      14         ('spec_version', properties.StringProperty(required=True, fixed='2.1')),
#      15         ('name', properties.StringProperty(required=True)),
#      16         ('description', properties.StringProperty()),
#      17         ('scope', properties.EnumProperty(required=True, allowed=['incident', 'campaign', 'threat-actor', 'malware', 'other'])),
#      18         ('start_refs', properties.ListProperty(properties.ReferenceProperty(valid_types=["attack-action", "attack-condition"]), required=True, ))
#      19     ]
#      20 )
#      21 class AttackFlow:
#      22     pass
#      24 @CustomObject(
#      25     'attack-action', [
#      26         ('type', properties.StringProperty(required=True, fixed='attack-action')),
#    (...)
#      40 )
#      41 class AttackAction:
#
# File /workspaces/ATTACK-RISK/.venv/lib/python3.12/site-packages/stix2/v21/sdo.py:871, in CustomObject.<locals>.wrapper(cls)
#     869     NameExtension.__name__ = 'ExtensionDefinition' + extension
#     870     cls.with_extension = extension_name
# --> 871 return _custom_object_builder(cls, type, _properties, '2.1', _DomainObject)
#
# File /workspaces/ATTACK-RISK/.venv/lib/python3.12/site-packages/stix2/custom.py:42, in _custom_object_builder(cls, type, properties, version, base_class)
#      38             self._inner['extensions'][ext] = class_for_type(ext, version, "extensions")()
#      40 _CustomObject.__name__ = cls.__name__
# ---> 42 _register_object(_CustomObject, version=version)
#      43 return _CustomObject
#
# File /workspaces/ATTACK-RISK/.venv/lib/python3.12/site-packages/stix2/registration.py:99, in _register_object(new_type, version)
#      97 OBJ_MAP = registry.STIX2_OBJ_MAPS[version]['objects']
#      98 if new_type._type in OBJ_MAP.keys():
# ---> 99     raise DuplicateRegistrationError("STIX Object", new_type._type)
#     100 OBJ_MAP[new_type._type] = new_type
#
# DuplicateRegistrationError: A(n) STIX Object with type 'attack-flow' already exists and cannot be registered again
